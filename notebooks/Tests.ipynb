# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

from bcd import BayesianChangepointDetection
from bcd.distributions import StudentT

import os
os.chdir('..')

# %%
def hazard(p):
    def geometric(t):
        return p * (1 - p) ** t
    return geometric

# %%
# Exponential distribution
data = np.concatenate((
    np.random.exponential(scale=1, size=100),
    np.random.exponential(scale=10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Gamma distribution
data = np.concatenate((
    np.random.gamma(1, size=100),
    np.random.gamma(10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Geometric distribution
data = np.concatenate((
    np.random.geometric(.1, size=100),
    np.random.geometric(1, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Student's t distribution
data = np.concatenate((
    np.random.standard_t(1, size=100),
    np.random.standard_t(10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Normal distribution
data = np.concatenate((
    np.random.normal(scale=1, size=100),
    np.random.normal(scale=10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Pareto distribution
data = np.concatenate((
    np.random.pareto(1, size=100),
    np.random.pareto(10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Poisson distribution
data = np.concatenate((
    np.random.poisson(lam=1, size=100),
    np.random.poisson(lam=10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Logistic distribution
data = np.concatenate((
    np.random.logistic(scale=1, size=100),
    np.random.logistic(scale=10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()

# %%
# Dirichlet distribution
data = np.concatenate((
    np.random.dirichlet(1, size=100),
    np.random.dirichlet(10, size=100)
    ))
detector = BayesianChangepointDetection(hazard(0.6), StudentT(0.1, 0.1, 1, 1))
results = [detector.step(datum) for datum in data]

plt.plot([result.argmax() for result in results])
plt.plot(data)
plt.axvline(x=100, color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-6f66bd35d475> in <module>()
#       1 # Dirichlet distribution
#       2 data = np.concatenate((
# ----> 3     np.random.dirichlet(1, size=100),
#       4     np.random.dirichlet(10, size=100)
#       5     ))
#
# mtrand.pyx in mtrand.RandomState.dirichlet (numpy/random/mtrand/mtrand.c:29265)()
#
# TypeError: object of type 'int' has no len()
